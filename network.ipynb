# %%
import socket


print(socket.gethostname())
print(socket.gethostbyname("vinodhpc"))
# Out:
# vinodhpc
# 192.168.1.12

# %%
import psutil

result=psutil.net_connections(kind="inet")

print(result)

for x in result:
    if x.status=="LISTEN":
        print(x.laddr.port ,"is open on ",x.laddr.ip)
# Out:
# [sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=60799), raddr=addr(ip='127.0.0.1', port=60798), status='ESTABLISHED', pid=18380), sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_DGRAM: 2>, laddr=addr(ip='192.168.56.1', port=24629), raddr=(), status='NONE', pid=23652), sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=60804), raddr=addr(ip='127.0.0.1', port=60805), status='ESTABLISHED', pid=18380), sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=9008), raddr=(), status='LISTEN', pid=19704), sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=addr(ip='127.0.0.1', port=59044), raddr=addr(ip='127.0.0.1', port=59045), status='ESTABLISHED', pid=22924), sconn(fd=-1, family=<AddressFamily.AF_INET: 2>, type=<SocketKind.SOCK_STREAM: 1>, laddr=
# ...
